# %%
import pandas as pd

import sys
sys.path.append("../src")

from config import url, file_name
from data.load_data import get_data
from data.clean_data import dataset_cleaned

# load row data
df = get_data(url, file_name)

# cleaned subset of the data
cdf = dataset_cleaned(df)

# %%
cdf
# Out:
#       MainBranch              Age           Employment  \
# 1      Developer  25-34 years old  Employed, full-time
# 2      Developer  45-54 years old  Employed, full-time
# 3      Developer  25-34 years old  Employed, full-time
# 4      Developer  25-34 years old                  NaN
# 5      Developer  35-44 years old  Employed, full-time
# ...          ...              ...                  ...
# 89162  Developer  35-44 years old  Employed, full-time
# 89166  Developer  18-24 years old                  NaN
# 89167  Developer  18-24 years old  Employed, full-time
# 89170  Developer  25-34 years old  Employed, full-time
# 89171  Developer  25-34 years old  Employed, full-time
#
#                                  RemoteWork  \
# 1                                    Remote
# 2      Hybrid (some remote, some in-person)
# 3      Hybrid (some remote, some in-person)
# 4                                    Remote
# 5                                    Remote
# ...                                     ...
# 89162                                Remote
# 89166                             In-person
# 89167                                Remote
# 89170  Hybrid (some remote, some in-person)
# 89171                             In-person
#
#                                                  EdLevel  YearsCode  \
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)       18.0
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)       27.0
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)       12.0
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)        6.0
# 5      Some college/university study without earning ...       21.0
# ...                                                  ...        ...
# 89162    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       30.0
# 89166  Some college/university study without earning ...        7.0
# 89167       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        6.0
# 89170    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       18.0
# 89171    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       20.0
#
#        YearsCodePro                             LanguageHaveWorkedWith  \
# 1               9.0                         HTML/CSS;JavaScript;Python
# 2              23.0                         Bash/Shell (all shells);Go
# 3               7.0  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4               4.0                     HTML/CSS;JavaScript;TypeScript
# 5              21.0  Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# ...             ...                                                ...
# 89162          24.0                                              C;C++
# 89166           2.0  Assembly;Bash/Shell (all shells);C;C#;C++;Java...
# 89167           2.0                Dart;HTML/CSS;JavaScript;TypeScript
# 89170           9.0           C#;F#;HTML/CSS;JavaScript;SQL;TypeScript
# 89171           9.0                         Java;JavaScript;TypeScript
#
#                                     DevType  \
# 1      Senior Executive (C-Suite, VP, etc.)
# 2                       Developer, back-end
# 3                      Developer, front-end
# 4                     Developer, full-stack
# 5                       Developer, back-end
# ...                                     ...
# 89162                   Developer, back-end
# 89166                 Developer, full-stack
# 89167                     Developer, mobile
# 89170               Other (please specify):
# 89171                 Developer, full-stack
#
#                                                  Country  ConvertedCompYearly  \
# 1                               United States of America             285000.0
# 2                               United States of America             250000.0
# 3                               United States of America             156000.0
# 4                                            Philippines              23456.0
# 5      United Kingdom of Great Britain and Northern I...              96828.0
# ...                                                  ...                  ...
# 89162                                             Brazil              50719.0
# 89166                                            Armenia              16917.0
# 89167                                              India              15752.0
# 89170                                             France              64254.0
# 89171                                             Greece              61041.0
#
#                        ICorPM  WorkExp  \
# 1              People manager     10.0
# 2      Individual contributor     23.0
# 3      Individual contributor      7.0
# 4      Individual contributor      6.0
# 5      Individual contributor     22.0
# ...                       ...      ...
# 89162          People manager     25.0
# 89166  Individual contributor      3.0
# 89167  Individual contributor      2.0
# 89170  Individual contributor      9.0
# 89171  Individual contributor      9.0
#
#                                                 Industry
# 1      Information Services, IT, Software Development...
# 2      Information Services, IT, Software Development...
# 3                                                    NaN
# 4                                                  Other
# 5                                                  Other
# ...                                                  ...
# 89162  Information Services, IT, Software Development...
# 89166                                 Financial Services
# 89167                       Retail and Consumer Services
# 89170                                              Other
# 89171  Information Services, IT, Software Development...
#
# [48016 rows x 14 columns]
